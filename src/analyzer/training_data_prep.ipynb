# %% [markdown]
# # 预备knowledge distillation数据

# %% [markdown]
# ##  数据载入

# %%
from db_service import DBService

# Get the singleton instance (connects on first call)
db_service = DBService()

# Get the database object
db = db_service.get_db()

# Get a specific collection
plugin_outputs_collection = db_service.get_collection("plugin_outputs")

# Use the collection...
build_count = plugin_outputs_collection.count_documents({})
print(f"Found {build_count} outputs.")

# Close connection when application exits (optional, depends on app lifecycle)
db_service.close_connection()
# Out:
# 2025-04-10 11:50:27,060 - db_service - ERROR - Failed to connect to MongoDB: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[2], line 4
#       1 from db_service import DBService
#       3 # Get the singleton instance (connects on first call)
# ----> 4 db_service = DBService()
#       6 # Get the database object
#       7 db = db_service.get_db()
#
# File /workspace/src/analyzer/db_service.py:46, in DBService.__new__(cls, mongo_uri)
#      44 cls._client = MongoClient(uri)
#      45 # The ismaster command is cheap and does not require auth.
# ---> 46 cls._client.admin.command('ismaster')
#      47 cls._db = cls._client[MONGO_DATABASE or 'cfed_builds'] # Default to cfed_builds if not specified
# ...

# %% [markdown]
# ## 设立数据解构服务将数据保存出pydantic模型

# %%
##
